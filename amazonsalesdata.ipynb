# %% [markdown]
# connecting the google drive to google colab

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# importing all the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# load the dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/dataanalystics/AmazonSalesRecords.csv')

# %% [markdown]
# checking the first 5 rows of dataset

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H  05-28-2010  669165933   6/27/2010        9925
# 1        Online              C  08-22-2012  963881480   9/15/2012        2804
# 2       Offline              L  05-02-2014  341417157  05-08-2014        1779
# 3        Online              C  06-20-2014  514321792  07-05-2014        8102
# 4       Offline              L  02-01-2013  115456712  02-06-2013        5062
#
# ...

# %% [markdown]
# to find all the unique values in REGION COLUMN

# %%
print(df['Region'].unique())
# Out:
# ['Australia and Oceania' 'Central America and the Caribbean' 'Europe'
#  'Sub-Saharan Africa' 'Asia' 'Middle East and North Africa'
#  'North America']

# %%
print(df['Sales Channel'].unique())
# Out:
# ['Offline' 'Online']

# %%
print(df['Country'].unique())
# Out:
# ['Tuvalu' 'Grenada' 'Russia' 'Sao Tome and Principe' 'Rwanda'
#  'Solomon Islands' 'Angola' 'Burkina Faso' 'Republic of the Congo'
#  'Senegal' 'Kyrgyzstan' 'Cape Verde' 'Bangladesh' 'Honduras' 'Mongolia'
#  'Bulgaria' 'Sri Lanka' 'Cameroon' 'Turkmenistan' 'East Timor' 'Norway'
#  'Portugal' 'New Zealand' 'Moldova ' 'France' 'Kiribati' 'Mali'
#  'The Gambia' 'Switzerland' 'South Sudan' 'Australia' 'Myanmar' 'Djibouti'
#  'Costa Rica' 'Syria' 'Brunei' 'Niger' 'Azerbaijan' 'Slovakia' 'Comoros'
#  'Iceland' 'Macedonia' 'Mauritania' 'Albania' 'Lesotho' 'Saudi Arabia'
#  'Sierra Leone' "Cote d'Ivoire" 'Fiji' 'Austria' 'United Kingdom'
#  'San Marino' 'Libya' 'Haiti' 'Gabon' 'Belize' 'Lithuania' 'Madagascar'
#  'Democratic Republic of the Congo' 'Pakistan' 'Mexico'
#  'Federated States of Micronesia' 'Laos' 'Monaco' 'Samoa ' 'Spain'
#  'Lebanon' 'Iran' 'Zambia' 'Kenya' 'Kuwait' 'Slovenia' 'Romania'
#  'Nicaragua' 'Malaysia' 'Mozambique']

# %% [markdown]
# check the info() of data to find either there are any null values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %% [markdown]
# check the object of date column and convert it to date time

# %%
df['Order Date']
# Out:
# 0     05-28-2010
# 1     08-22-2012
# 2     05-02-2014
# 3     06-20-2014
# 4     02-01-2013
#          ...
# 95    07-26-2011
# 96    11-11-2011
# 97    06-01-2016
# 98    07-30-2015
# 99    02-10-2012
# Name: Order Date, Length: 100, dtype: object

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df ["Order Date"]
# Out:
# 0    2010-05-28
# 1    2012-08-22
# 2    2014-05-02
# 3    2014-06-20
# 4    2013-02-01
#         ...
# 95   2011-07-26
# 96   2011-11-11
# 97   2016-06-01
# 98   2015-07-30
# 99   2012-02-10
# Name: Order Date, Length: 100, dtype: datetime64[ns]

# %%
df["Order Date"].dt.year
# Out:
# 0     2010
# 1     2012
# 2     2014
# 3     2014
# 4     2013
#       ...
# 95    2011
# 96    2011
# 97    2016
# 98    2015
# 99    2012
# Name: Order Date, Length: 100, dtype: int64

# %%
df["Order Date"].dt.month
# Out:
# 0      5
# 1      8
# 2      5
# 3      6
# 4      2
#       ..
# 95     7
# 96    11
# 97     6
# 98     7
# 99     2
# Name: Order Date, Length: 100, dtype: int64

# %% [markdown]
# break the date column into the year and month.

# %%
df["year"] = df["Order Date"].dt.year
df["month"] = df["Order Date"].dt.month
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# year              0
# month             0
# dtype: int64

# %% [markdown]
# count the number on total venues in a months

# %%
revenue_by_month=df.loc[:, ['Total Revenue', 'month']]
revenue_by_month ['month'].value_counts()
# Out:
# 2     13
# 7     12
# 5     11
# 10    11
# 6     10
# 4      9
# 11     9
# 1      7
# 12     5
# 9      5
# 8      4
# 3      4
# Name: month, dtype: int64

# %% [markdown]
# converted the months from numbers values to words.

# %%
df['month']=df['Order Date'].dt.strftime('%B')

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
revenue_by_month=df.loc[:, ['Total Revenue', 'month']]
revenue_by_month ['month'].value_counts()
# Out:
# February     13
# July         12
# May          11
# October      11
# June         10
# April         9
# November      9
# January       7
# December      5
# September     5
# August        4
# March         4
# Name: month, dtype: int64

# %%
revenue_by_year=df.loc[:, ['Total Revenue', 'year']]
revenue_by_year ['year'].value_counts()
# Out:
# 2012    22
# 2014    15
# 2013    12
# 2011    12
# 2015    11
# 2010    10
# 2016    10
# 2017     8
# Name: year, dtype: int64

# %% [markdown]
# sales total calculated and checked with the total revenue.

# %%
df['Sales_Total']=\
df['Units Sold'] *df['Unit Price']

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
sales_by_month=df.loc [:,['Sales_Total', 'month']]
sales_by_month['month'].value_counts()
# Out:
# February     13
# July         12
# May          11
# October      11
# June         10
# April         9
# November      9
# January       7
# December      5
# September     5
# August        4
# March         4
# Name: month, dtype: int64

# %% [markdown]
# sum of all the months revenue

# %%
ff=sales_by_month.groupby('month').sum().unstack() ['Sales_Total']

# %%
ff
# Out:
# month
# April        16187186.33
# August        1128164.91
# December      7249462.12
# February     24740517.77
# January      10482467.12
# July         15669518.50
# June          5230325.77
# March         2274823.87
# May          13215739.99
# November     20568222.76
# October      15287576.61
# September     5314762.56
# dtype: float64

# %%
sales_by_year=df.loc [:,['Sales_Total', 'year']]
sales_by_year['year'].value_counts()
# Out:
# 2012    22
# 2014    15
# 2013    12
# 2011    12
# 2015    11
# 2010    10
# 2016    10
# 2017     8
# Name: year, dtype: int64

# %%
ff=sales_by_year.groupby('year').sum().unstack() ['Sales_Total']

# %% [markdown]
# yearly total revenue generation

# %%
ff
# Out:
# year
# 2010    19186024.92
# 2011    11129166.07
# 2012    31898644.52
# 2013    20330448.66
# 2014    16630214.43
# 2015    12427982.86
# 2016    12372867.22
# 2017    13373419.63
# dtype: float64

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...
